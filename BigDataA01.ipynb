# %% [markdown]
# # Assignment 1 | L1F20BSCS0949

# %%
import pandas as pd

# %%
df=pd.read_csv('jsrt_metadata.csv')

# %%
df
# Out:
#          study_id  subtlety  size age  gender       x       y       state  \
# 0    JPCLN001.png       5.0  15.0  53    Male  1634.0   692.0   malignant
# 1    JPCLN002.png       5.0  30.0  78  Female  1614.0  1090.0      benign
# 2    JPCLN003.png       5.0  30.0  63  Female  1303.0   447.0   malignant
# 3    JPCLN004.png       5.0  14.0  68  Female   606.0   836.0      benign
# 4    JPCLN005.png       5.0  35.0  73  Female  1438.0   692.0   malignant
# ..            ...       ...   ...  ..     ...     ...     ...         ...
# 242  JPCNN089.png       NaN   NaN  50    Male     NaN     NaN  non-nodule
# 243  JPCNN090.png       NaN   NaN  68  Female     NaN     NaN  non-nodule
# 244  JPCNN091.png       NaN   NaN  81    Male     NaN     NaN  non-nodule
# 245  JPCNN092.png       NaN   NaN  70  Female     NaN     NaN  non-nodule
# 246  JPCNN093.png       NaN   NaN  41    Male     NaN     NaN  non-nodule
#
#                position           diagnosis
# ...

# %%
mx=df['diagnosis'].value_counts().idxmax()

# %%
import numpy as np

# %%
df.isnull().sum()
# Out:
# study_id      0
# subtlety     93
# size         93
# age           0
# gender        0
# x            93
# y            93
# state         0
# position     93
# diagnosis     0
# dtype: int64

# %%
df['diagnosis'].replace(np.nan,mx,inplace=True)
mx=df['subtlety'].value_counts().idxmax()
df['subtlety'].replace(np.nan,mx,inplace=True)
mx=df['size'].value_counts().idxmax()
df['size'].replace(np.nan,mx,inplace=True)
m = df['x'].astype('float').mean()
df['x'].replace(np.nan,m,inplace=True)
m = df['y'].astype('float').mean()
df['y'].replace(np.nan,m,inplace=True)
mx=df['position'].value_counts().idxmax()
df['position'].replace(np.nan,mx,inplace=True)

# %%
df
# Out:
#          study_id  subtlety  size age  gender            x            y  \
# 0    JPCLN001.png       5.0  15.0  53    Male  1634.000000   692.000000
# 1    JPCLN002.png       5.0  30.0  78  Female  1614.000000  1090.000000
# 2    JPCLN003.png       5.0  30.0  63  Female  1303.000000   447.000000
# 3    JPCLN004.png       5.0  14.0  68  Female   606.000000   836.000000
# 4    JPCLN005.png       5.0  35.0  73  Female  1438.000000   692.000000
# ..            ...       ...   ...  ..     ...          ...          ...
# 242  JPCNN089.png       3.0  15.0  50    Male   937.324675   868.623377
# 243  JPCNN090.png       3.0  15.0  68  Female   937.324675   868.623377
# 244  JPCNN091.png       3.0  15.0  81    Male   937.324675   868.623377
# 245  JPCNN092.png       3.0  15.0  70  Female   937.324675   868.623377
# 246  JPCNN093.png       3.0  15.0  41    Male   937.324675   868.623377
#
#           state            position           diagnosis
# ...

# %%
import matplotlib as plt

# %%
from matplotlib import pyplot

# %%
#1.
print(df['diagnosis'].value_counts())
plt.pyplot.hist(df['diagnosis'].value_counts())
# Out:
# lung cancer                                       149
# lung cancer(adenocarcinoma)                        23
# tuberculoma                                        14
# granuloma                                           8
# lung cancer(bronchioloalveolar cell carcinoma)      7
# unknown                                             4
# metastasis of colon cancer                          4
# inflammatory mass                                   4
# pulmonary tuberculosis                              3
# lung abscess                                        2
# Cryptococcosis                                      2
# lung cancer(squamous cell carcinoma)                2
# Inflammatory mass                                   2
# pulmonary hematoma                                  2
# susp. inflammatory mass                             2
# hamartoma                                           2
# sclerosing hemangioma                               2
# ...

# %%
#2.
print(df[['state','diagnosis']].value_counts())
plt.pyplot.pie(df[['state','diagnosis']].value_counts(),autopct='%1.1f%%',startangle=90,)
# Out:
# state       diagnosis
# non-nodule  lung cancer                                       93
# malignant   lung cancer                                       56
#             lung cancer(adenocarcinoma)                       23
# benign      tuberculoma                                       14
#             granuloma                                          8
# malignant   lung cancer(bronchioloalveolar cell carcinoma)     7
#             metastasis of colon cancer                         4
# benign      inflammatory mass                                  4
#             unknown                                            4
#             pulmonary tuberculosis                             3
#             susp. inflammatory mass                            2
# malignant   lung cancer(squamous cell carcinoma)               2
# benign      Inflammatory mass                                  2
#             Cryptococcosis                                     2
# ...

# %%
#3.
print(df[['gender','diagnosis']].value_counts())
plt.pyplot.pie(df[['gender','diagnosis']].value_counts(),autopct='%1.1f%%',startangle=90)
# Out:
# gender  diagnosis
# Male    lung cancer                                       75
# Female  lung cancer                                       74
#         lung cancer(adenocarcinoma)                       15
# Male    tuberculoma                                        9
#         lung cancer(adenocarcinoma)                        8
#         granuloma                                          6
# Female  tuberculoma                                        5
#         lung cancer(bronchioloalveolar cell carcinoma)     4
#         unknown                                            4
# Male    pulmonary tuberculosis                             3
# Female  metastasis of colon cancer                         3
# Male    lung cancer(bronchioloalveolar cell carcinoma)     3
# Female  inflammatory mass                                  2
#         Inflammatory mass                                  2
# Male    lung cancer(squamous cell carcinoma)               2
# ...
